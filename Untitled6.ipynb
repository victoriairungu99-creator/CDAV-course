# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriairungu99-creator/CDAV-course/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("-------------------")
name=input("Enter name")
age=input("Enter age")
course=input("Enter course")
print("===================")
print("STUDENT PROFILE")
print("==================")
print("Name:",name)
print("Age:",age)
print("Course:",course)
# Out:
# -------------------
# Enter nameVicky
# Enter age21
# Enter courseData analytics
# ...
# STUDENT PROFILE
# ...
# Name: Vicky
# Age: 21
# Course: Data analytics

# %%
item=input("Enter item of choice: ")
quantity=float(input("Enter number of items: "))
price=float(input("Enter price of item: "))
print("Item:",item)
print("Quantity:",quantity)
print("Total=",price*quantity)
# Out:
# Enter item of choice: Apple
# Enter number of items: 3
# Enter price of item: 1.5
# Item: Apple
# Quantity: 3.0
# Total= 4.5

# %%
print(20>10)
print(20<10)
print(5==5)
print(5!=5)
# Out:
# True
# False
# True
# False
