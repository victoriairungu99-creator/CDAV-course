# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriairungu99-creator/CDAV-course/blob/main/day_8_Wednesday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Functions
#
# -Self-contained,reusable block of code that executes a specific task
#
# -types of functions:
#
# -Inbuilt
# :part of python language(already exists)eg, print(), len()
#
# User-defined:Created by the programmer, has top be created first so as to be used
#
# Functions from packages:A package is a set of reusable code consisting of functions,classes,variables etc that was created by someone else before and can be shared across different peoiple in different projects
#
# -if you want to use a package in your project, you have to import it first for it to be available in your runtime then use the package.what you want to find eg, math.cbrt(1000)
#
# -If you have another word that matches your packaging like math, it will bring a clash therefore you alis the math(rename it) using keyword 'as' eg, import math as mt, import numpy as np, from math import sqrt as sqt

# %%
import math

# %%
math.cbrt(400)
# Out:
# 7.368062997280773

# %%
import pandas
pandas.__version__
# Out:
# '2.2.2'

# %%
from math import cbrt,sqrt
cbrt(876)
# Out:
# 9.568298205117985

# %%
sqrt(25)
# Out:
# 5.0

# %% [markdown]
# #User defined functions
#
# (_) is used for return(to return a value to enable proper printing)

# %%
#function that greets people in a random language
def greeter():
  import random
  greetings=["bonjour",
             "jambo",
             "hi",
             "konichiwa"]
  print(greetings[random.randint(0,3)])

# %%
greeter()
print(greeter(),"John")
# Out:
# bonjour
# bonjour
# None John
